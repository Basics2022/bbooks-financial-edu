# %% [markdown]
# ()=
# # Equity investing: correlations, plots, and fun facts

# %%
import numpy as np
import yfinance as yf

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Return of Equity Markets

# %%
sp500 = yf.download('^GSPC', start='1950-01-01', end='2025-07-01')['Close']
sp500 = sp500.resample('ME').last()

plt.figure(figsize=(12, 6))
plt.plot(sp500.index, sp500, label='S&P 500')
plt.yscale('log')
plt.title('S&P 500 Price Index (Log Scale)')
plt.ylabel('Price (log)')
plt.xlabel('Date')
plt.grid(True, which='both', ls='--', lw=0.5)
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-10-3592326793.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sp500 = yf.download('^GSPC', start='1950-01-01', end='2025-07-01')['Close']
# [*********************100%***********************]  1 of 1 completed

# %%
sp500
# Out:
# Ticker            ^GSPC
# Date
# 1950-01-31    17.049999
# 1950-02-28    17.219999
# 1950-03-31    17.290001
# 1950-04-30    17.959999
# 1950-05-31    18.780001
# ...                 ...
# 2025-02-28  5954.500000
# 2025-03-31  5611.850098
# 2025-04-30  5569.060059
# 2025-05-31  5911.689941
# 2025-06-30  6204.950195
#
# [906 rows x 1 columns]

# %% [markdown]
# ## Historical Rolling Returns

# %%
returns = sp500.pct_change().dropna()
cumulative_returns = {}
for years in [3, 5, 10]:
    months = years * 12
    rolling = sp500.pct_change(periods=months)
    cumulative_returns[years] = rolling.dropna()

import seaborn as sns

plt.figure(figsize=(15, 5))
for i, y in enumerate([3, 5, 10]):
    plt.subplot(1, 3, i+1)
    sns.histplot(cumulative_returns[y]*100, bins=40, kde=True)
    plt.title(f'{y}-Year Rolling Returns')
    plt.xlabel('Return (%)')
    plt.axvline(np.mean(cumulative_returns[y]*100), color='r', linestyle='--', label='Mean')
    plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Return vs. Evaluation - Shiller data
#
# **References.** Online data from Robert Shiller:
# - https://shillerdata.com/, ie_data.xls;
# - old website at Yale:
# http://www.econ.yale.edu/~shiller/data.htm

# %%
# Load Shiller data
url = 'https://www.econ.yale.edu/~shiller/data/ie_data.xls'
shiller = pd.read_excel(url, sheet_name='Data', skiprows=7)

# Keep monthly data from 1900 onwards
shiller = shiller[shiller['Date'] >= 1900]
shiller['Date'] = pd.to_datetime(shiller['Date'], format='%Y.%m')
shiller.set_index('Date', inplace=True)

# Compute forward 10-year returns
shiller['10y_forward_return'] = shiller['Real Price'].shift(-120) / shiller['Real Price'] - 1

# Plot CAPE vs future 10y return
plt.figure(figsize=(10, 6))
plt.scatter(shiller['CAPE'], shiller['10y_forward_return'], alpha=0.5)
plt.title('Shiller CAPE vs Forward 10-Year Real Returns')
plt.xlabel('Shiller CAPE')
plt.ylabel('10-Year Forward Return')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/lib/python3.11/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1347             try:
# -> 1348                 h.request(req.get_method(), req.selector, req.data, headers,
#    1349                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /usr/lib/python3.11/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1302         """Send a complete request to the server."""
# -> 1303         self._send_request(method, url, body, headers, encode_chunked)
#    1304
#
# /usr/lib/python3.11/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1348             body = _encode(body, 'body')
# -> 1349         self.endheaders(body, encode_chunked=encode_chunked)
#    1350
#
# ...

# %%
# Using already processed Shiller and S&P data
# Join PE with returns
merged = shiller[['CAPE']].copy()
for y in [1, 3, 5, 10]:
    merged[f'{y}Y_fwd_ret'] = shiller['Real Price'].shift(-y*12) / shiller['Real Price'] - 1

sns.pairplot(merged.dropna(), vars=[f'{y}Y_fwd_ret' for y in [1, 3, 5, 10]], hue='CAPE', palette='coolwarm')
